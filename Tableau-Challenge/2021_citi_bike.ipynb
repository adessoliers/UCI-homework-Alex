# %%
import pandas as pd

# %%
data = pd.read_csv("Resources/JC-202101-citibike-tripdata.csv")
data.head()
# Out:
#    tripduration starttime stoptime  start station id start station name  \
# 0           266   03:35.5  08:01.8              3273       Manila & 1st
# 1          1543   23:32.9  49:16.1              3681           Grand St
# 2          1461   23:50.8  48:12.6              3681           Grand St
# 3           793   31:09.1  44:22.9              3185          City Hall
# 4           596   35:52.2  45:48.8              3639         Harborside
#
#    start station latitude  start station longitude  end station id  \
# 0               40.721651               -74.042884            3209
# 1               40.715178               -74.037683            3213
# 2               40.715178               -74.037683            3213
# 3               40.717733               -74.043845            3199
# 4               40.719252               -74.034234            3209
#
#   end station name  end station latitude  end station longitude  bikeid  \
# ...

# %%
data.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
data = data.rename(columns={"tripduration": "Trip Duration (secs)"})

# %%
data.loc[(data["gender"] == 1, "gender")] = "male"
data.loc[(data["gender"] == 2, "gender")] = "female"

# %%
data = data[data.gender != 0]

# %%
data.head()
# Out:
#    Trip Duration (secs) starttime stoptime  start station id  \
# 0                   266   03:35.5  08:01.8              3273
# 1                  1543   23:32.9  49:16.1              3681
# 2                  1461   23:50.8  48:12.6              3681
# 5                   144   39:55.6  42:19.8              3269
# 7                   265   12:20.8  16:46.4              3276
#
#   start station name  start station latitude  start station longitude  \
# 0       Manila & 1st               40.721651               -74.042884
# 1           Grand St               40.715178               -74.037683
# 2           Grand St               40.715178               -74.037683
# 5    Brunswick & 6th               40.726012               -74.050389
# 7   Marin Light Rail               40.714584               -74.042817
#
#    end station id  end station name  end station latitude  \
# 0            3209      Brunswick St             40.724176
# ...

# %%
data.to_csv("Resources/2021_citi_bike.csv", index=False)
